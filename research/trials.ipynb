# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key']
# Out:
# 'val'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key
# Out:
# 'val'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
# ensure annotations

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
## Download data from Google Drive

import gdown

# %%
url="https://drive.google.com/file/d/172xRLsitipzymBi9EslZ2u2VZN3OJwIz/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '172xRLsitipzymBi9EslZ2u2VZN3OJwIz'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=172xRLsitipzymBi9EslZ2u2VZN3OJwIz
# From (redirected): https://drive.google.com/uc?export=download&id=172xRLsitipzymBi9EslZ2u2VZN3OJwIz&confirm=t&uuid=9071b5f8-3ae3-4e6e-b067-10049e25b95a
# To: g:\Python Codes\kidney-disease-detection-mlops\research\kidney-CT-Scan-data.zip
# 100%|██████████| 940M/940M [13:03<00:00, 1.20MB/s]
# 'kidney-CT-Scan-data.zip'
